# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsahabuddin01/Python/blob/main/projects/Tic_Tac_Toe_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Our website has a 400x500 space we’d like to replace with something fun. Please build a Tic Tac Toe game with those exact dimensions. Build it in python using the pygame library. Do not include the implementation for embedding it on the website, we’ll handle that part, the game should work by itself. The game should display a legible state (whose turn it is or win/lose/draw) at all times. Make sure the game resets when someone wins or when there’s a draw. After a winning move, a red line should cross the center of the three X’s or O’s that end in the winning move, it should then pause for 10 seconds and restart the game.**

# %% [markdown]
# **Instructions for testing and local use**
#
# * Ensure you have `pygame` installed in your current python environment.
#
# * Run the script from your console by calling `python script_name.py`
#
# * X goes first, a red line will apear once a player has won.
#
# * Play the game until one player wins or there is a draw.
#
# * Close the window once you've finished playing.

# %% [markdown]
#  A Pygame implementation of a Tic Tac Toe game with dimensions 400x500.
#  1. The game will wait and then reset whenever there is a draw or one of the players wins.
#  2. When a player wins, it generates a red line crossing all three squares that were a part of the winning move.

# %%
import pygame as pg
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import sys

import time

from pygame.locals import *



# initialize variables

current_player = 'x'

current_winner = None

is_draw = None



WIDTH = 400

HEIGHT = 400 # Add 100 later for the

BACKGROUND = (255, 255, 255)

LINE_COLOR = (0, 0, 0)





grid = [[None]*3, [None]*3, [None]*3]



pg.init()

FPS = 30

clock = pg.time.Clock()



screen = pg.display.set_mode((WIDTH, HEIGHT + 100), 0, 32) # 400 x 500 display

pg.display.set_caption("Tic Tac Toe")



size = 80 # size of the X / O marks



def game_initiating_window():

    """initializes game window"""

    pg.display.update()

    time.sleep(3)

    screen.fill(BACKGROUND)

    pg.draw.line(screen, LINE_COLOR, (WIDTH / 3, 0), (WIDTH / 3, HEIGHT), 7)

    pg.draw.line(screen, LINE_COLOR, (WIDTH / 3 * 2, 0), (WIDTH / 3 * 2, HEIGHT), 7)

    pg.draw.line(screen, LINE_COLOR, (0, HEIGHT / 3), (WIDTH, HEIGHT / 3), 7)

    pg.draw.line(screen, LINE_COLOR, (0, HEIGHT / 3 * 2), (WIDTH, HEIGHT / 3 * 2), 7)

    draw_status()



def draw_status():

    """draws the status bar"""

    global is_draw

    if current_winner is None:

        message = current_player.upper() + "'s Turn"

    else:

        message = current_winner.upper() + " won !"

    if is_draw:

        message = "Game Draw !"

    font = pg.font.Font(None, 30)

    text = font.render(message, 1, (255, 255, 255))

    screen.fill((0, 0, 0), (0, 400, 475, 100))

    text_rect = text.get_rect(center=(WIDTH / 2, HEIGHT/2))

    screen.blit(text, text_rect)

    pg.display.update()



def check_win():

    """checks game grid for wins or draws"""

    global grid, current_winner, is_draw

    for row in range(0, 3):

        if (grid[row][0] == grid[row][1] == grid[row][2]) and (grid[row][0] is not None):

            current_winner = grid[row][0]

            pg.draw.line(screen, (250, 0, 0),

                         (0, (row + 1)*HEIGHT / 3 - HEIGHT / 6),

                         (WIDTH, (row + 1)*HEIGHT / 3 - HEIGHT / 6), 4)

            break

    for col in range(0, 3):

        if (grid[0][col] == grid[1][col] == grid[2][col]) and (grid[0][col] is not None):

            current_winner = grid[0][col]

            pg.draw.line(screen, (250, 0, 0),

                         ((col + 1) * WIDTH / 3 - WIDTH / 6, 0),

                         ((col + 1) * WIDTH / 3 - WIDTH / 6, HEIGHT), 4)

            break

    if (grid[0][0] == grid[1][1] == grid[2][2]) and (grid[0][0] is not None):

        current_winner = grid[0][0]

        pg.draw.line(screen, (250, 70, 70), (50, 50), (350, 350), 4)

    if (grid[0][2] == grid[1][1] == grid[2][0]) and (grid[0][2] is not None):

        current_winner = grid[0][2]

        pg.draw.line(screen, (250, 70, 70), (350, 50), (50, 350), 4)

    if (all([all(row) for row in grid]) and current_winner is None):

        is_draw = True

    draw_status()



def drawXO(row, col):

    """draws the X's and O's on the board"""

    global grid, current_player

    if row == 1:

        pos_x = 50

    if row == 2:

        pos_x = WIDTH / 3 + 30

    if row == 3:

        pos_x = WIDTH / 3 * 2 + 30

    if col == 1:

        pos_y = 25

    if col == 2:

        pos_y = HEIGHT / 3 + 30

    if col == 3:

        pos_y = HEIGHT / 3 * 2 + 30

    grid[row-1][col-1] = current_player

    if current_player == 'x':

        pg.draw.line(screen, (0, 0, 0), (pos_y, pos_x), (pos_y + size, pos_x + size), 5)

        pg.draw.line(screen, (0, 0, 0), (pos_y, pos_x + size), (pos_y + size, pos_x), 5)

        current_player = 'o'

    else:

        center = (pos_y + size // 2, pos_x + size // 2)

        radius = size // 2 - 5

        pg.draw.circle(screen, (0, 0, 0), center, radius, 5)

        current_player = 'x'

    pg.display.update()



def user_click():

    """finds the position of the user's click"""

    x, y = pg.mouse.get_pos()

    if (x < WIDTH / 3):

        col = 1

    elif (x < WIDTH / 3 * 2):

        col = 2

    elif (x < WIDTH):

        col = 3

    else:

        col = None

    if (y < HEIGHT / 3):

        row = 1

    elif (y < HEIGHT / 3 * 2):

        row = 2

    elif (y < HEIGHT):

        row = 3

    else:

        row = None

    if (row and col and grid[row-1][col-1] is None):

        drawXO(row, col)

        check_win()



def reset_game():

    """restarts game on win or draw"""

    global grid, current_winner, current_player, is_draw

    time.sleep(3)

    current_player = 'x'

    is_draw = False

    game_initiating_window()

    current_winner = None

    grid = [[None]*3, [None]*3, [None]*3]



game_initiating_window()



while True: # continue loop until user closes the window

    for event in pg.event.get(): # check for new events

        if event.type == QUIT:

            pg.quit()

            sys.exit()

        elif event.type == MOUSEBUTTONDOWN:

            user_click()

            if (current_winner or is_draw):

                reset_game()

    pg.display.update()

    clock.tick(FPS)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fd9f1b61be00> in <cell line: 0>()
#     301                 reset_game()
#     302
# --> 303     pg.display.update()
#     304
#     305     clock.tick(FPS)
#
# KeyboardInterrupt:

# %% [markdown]
# 1️⃣ Incorrect Text Position in the Status Bar
# Issue:
# The status text (whose turn it is or who won) is not positioned correctly inside the bottom 100 pixels of the screen.
# The existing text placement logic uses:
# python
# Copy
# Edit
# text_rect = text.get_rect(center=(WIDTH / 2, HEIGHT / 2))
# Problem: This places the text in the middle of the game board (400px area) instead of inside the status bar at the bottom.
# Fix:
# Adjust text positioning to the extra 100-pixel area.
# Solution Code:
# python
# Copy
# Edit
# text_rect = text.get_rect(center=(WIDTH / 2, HEIGHT + STATUS_HEIGHT / 2))
#
#
# 2️⃣ Missing Separator Between Game Board and Status Bar
# Issue:
# The prompt specifies a 400x500 game area, where the extra 100 pixels are dedicated to the status display.
# There is no visual separation between the game board (400x400) and the status area (100px).
# Fix:
# Add a horizontal line at HEIGHT to visually separate the game board from the status bar.
# Solution Code:
# python
# Copy
# Edit
# pg.draw.line(screen, LINE_COLOR, (0, HEIGHT), (WIDTH, HEIGHT), 7)
#
#
# 3️⃣ Incorrect Red Line for Diagonal Wins
# Issue:
# The red winning line for diagonals uses hardcoded coordinates, which can be inaccurate and does not scale dynamically:
# python
# Copy
# Edit
# pg.draw.line(screen, (250, 70, 70), (50, 50), (350, 350), 4)
# Problem: If the screen size ever changes, this hardcoded approach will not dynamically adjust to the correct diagonal path.
# Fix:
# Use dynamic calculations based on WIDTH and HEIGHT instead of hardcoded values.
# Solution Code:
# python
# Copy
# Edit
# pg.draw.line(screen, (250, 70, 70), (0, 0), (WIDTH, HEIGHT), 4)  # Left-to-right diagonal
# pg.draw.line(screen, (250, 70, 70), (WIDTH, 0), (0, HEIGHT), 4)  # Right-to-left diagonal
#
#
# 4️⃣ Incorrect Game Reset Time (3 Seconds Instead of 10)
# Issue:
# The prompt specifies that the game should pause for 10 seconds before restarting.
# The given code only waits for 3 seconds in reset_game():
# python
# Copy
# Edit
# time.sleep(3)
# Fix:
# Increase the sleep time from 3 seconds to 10 seconds.
# Solution Code:
# python
# Copy
# Edit
# time.sleep(10)
#
#
#
# 5️⃣ Game Allows Clicking in the Status Area
# Issue:
# The user_click() function does not check if the click happens inside the game board.
# Problem: Players can click inside the 100-pixel status bar, which should not be interactive.
# Existing Code:
# python
# Copy
# Edit
# x, y = pg.mouse.get_pos()
# Fix:
# Ignore clicks if y > HEIGHT (which means it’s inside the status bar).
# Solution Code:
# python
# Copy
# Edit
# if y > HEIGHT:  # Ignore clicks in the status area
#     return
#
#
#
# 6️⃣ Inefficient Handling of Grid Position Calculation
# Issue:
# The code manually calculates where X or O should be drawn.
# This repeats unnecessary if conditions for each row/column.
# Fix:
# Use cleaner and more efficient calculations.
# Solution Code:
# python
# Copy
# Edit
# pos_x = (col - 1) * WIDTH / 3 + WIDTH / 6
# pos_y = (row - 1) * HEIGHT / 3 + HEIGHT / 6

# %% [markdown]
# **Final Updated Code**

# %%
import pygame as pg
import sys
import time
from pygame.locals import *

# Initialize variables
current_player = 'x'
current_winner = None
is_draw = None

WIDTH, HEIGHT = 400, 400  # Game grid size
STATUS_HEIGHT = 100  # Extra 100 pixels for the status bar
SCREEN_HEIGHT = HEIGHT + STATUS_HEIGHT  # Total display height

BACKGROUND = (255, 255, 255)
LINE_COLOR = (0, 0, 0)

grid = [[None] * 3 for _ in range(3)]

pg.init()
FPS = 30
clock = pg.time.Clock()

# Initialize game screen
screen = pg.display.set_mode((WIDTH, SCREEN_HEIGHT), 0, 32)
pg.display.set_caption("Tic Tac Toe")

def game_initiating_window():
    """Initializes game window"""
    screen.fill(BACKGROUND)

    # Draw board grid
    for i in range(1, 3):
        pg.draw.line(screen, LINE_COLOR, (WIDTH / 3 * i, 0), (WIDTH / 3 * i, HEIGHT), 7)
        pg.draw.line(screen, LINE_COLOR, (0, HEIGHT / 3 * i), (WIDTH, HEIGHT / 3 * i), 7)

    # Draw status bar separator
    pg.draw.line(screen, LINE_COLOR, (0, HEIGHT), (WIDTH, HEIGHT), 7)

    draw_status()
    pg.display.update()

def draw_status():
    """Draws the status bar"""
    screen.fill((0, 0, 0), (0, HEIGHT, WIDTH, STATUS_HEIGHT))

    message = f"{current_player.upper()}'s Turn" if not current_winner and not is_draw else \
              (f"{current_winner.upper()} won!" if current_winner else "Game Draw!")

    font = pg.font.Font(None, 40)
    text = font.render(message, True, (255, 255, 255))
    text_rect = text.get_rect(center=(WIDTH / 2, HEIGHT + STATUS_HEIGHT / 2))
    screen.blit(text, text_rect)
    pg.display.update()

def user_click():
    """Handles user clicks to determine grid position"""
    x, y = pg.mouse.get_pos()
    if y > HEIGHT:  # Ignore clicks in the status area
        return

    col = x // (WIDTH // 3) + 1
    row = y // (HEIGHT // 3) + 1

    if grid[row - 1][col - 1] is None:
        drawXO(row, col)
        check_win()

def reset_game():
    """Resets the game after win or draw"""
    global grid, current_winner, current_player, is_draw
    time.sleep(10)  # Correct 10-second wait time
    grid = [[None] * 3 for _ in range(3)]
    current_winner = None
    is_draw = False
    current_player = 'x'
    game_initiating_window()

# Start game
game_initiating_window()

while True:
    for event in pg.event.get():
        if event.type == QUIT:
            pg.quit()
            sys.exit()
        elif event.type == MOUSEBUTTONDOWN:
            user_click()
            if current_winner or is_draw:
                reset_game()

    pg.display.update()
    clock.tick(FPS)
